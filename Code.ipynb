# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\data'

# %%
os.chdir("C:/Users/Lenovo/Desktop/data")
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Desktop\\data'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv('data.csv')
data
# Out:
#      Serial_No  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  \
# 0            1        337          118                  4  4.5  4.5  9.65
# 1            2        324          107                  4  4.0  4.5  8.87
# 2            3        316          104                  3  3.0  3.5  8.00
# 3            4        322          110                  3  3.5  2.5  8.67
# 4            5        314          103                  2  2.0  3.0  8.21
# 5            6        330          115                  5  4.5  3.0  9.34
# 6            7        321          109                  3  3.0  4.0  8.20
# 7            8        308          101                  2  3.0  4.0  7.90
# 8            9        302          102                  1  2.0  1.5  8.00
# 9           10        323          108                  3  3.5  3.0  8.60
# 10          11        325          106                  3  3.5  4.0  8.40
# 11          12        327          111                  4  4.0  4.5  9.00
# ...

# %%
data=data.drop(['Serial_No'],axis=1)
data
# Out:
#      GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  CGPA  Research   COA
# 0          337          118                  4  4.5  4.5  9.65         1  0.92
# 1          324          107                  4  4.0  4.5  8.87         1  0.76
# 2          316          104                  3  3.0  3.5  8.00         1  0.72
# 3          322          110                  3  3.5  2.5  8.67         1  0.80
# 4          314          103                  2  2.0  3.0  8.21         0  0.65
# 5          330          115                  5  4.5  3.0  9.34         1  0.90
# 6          321          109                  3  3.0  4.0  8.20         1  0.75
# 7          308          101                  2  3.0  4.0  7.90         0  0.68
# 8          302          102                  1  2.0  1.5  8.00         0  0.50
# 9          323          108                  3  3.5  3.0  8.60         0  0.45
# 10         325          106                  3  3.5  4.0  8.40         1  0.52
# ...

# %%
COA= data['COA']
COA
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
# 5      0.90
# 6      0.75
# 7      0.68
# 8      0.50
# 9      0.45
# 10     0.52
# 11     0.84
# 12     0.78
# 13     0.62
# 14     0.61
# 15     0.54
# 16     0.66
# 17     0.65
# 18     0.63
# 19     0.62
# 20     0.64
# 21     0.70
# 22     0.94
# 23     0.95
# 24     0.97
# 25     0.94
# 26     0.76
# 27     0.44
# 28     0.46
# 29     0.54
#        ...
# 370    0.72
# 371    0.89
# 372    0.95
# 373    0.79
# 374    0.39
# 375    0.38
# 376    0.34
# 377    0.47
# 378    0.56
# 379    0.71
# 380    0.78
# 381    0.73
# 382    0.82
# 383    0.62
# 384    0.96
# 385    0.96
# 386    0.46
# 387    0.53
# 388    0.49
# 389    0.76
# 390    0.64
# 391    0.71
# 392    0.84
# 393    0.77
# 394    0.89
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: COA, Length: 400, dtype: float64

# %%
GRE=data['GRE_Score']
GRE
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
# 5      330
# 6      321
# 7      308
# 8      302
# 9      323
# 10     325
# 11     327
# 12     328
# 13     307
# 14     311
# 15     314
# 16     317
# 17     319
# 18     318
# 19     303
# 20     312
# 21     325
# 22     328
# 23     334
# 24     336
# 25     340
# 26     322
# 27     298
# 28     295
# 29     310
#       ...
# 370    310
# 371    324
# 372    336
# 373    321
# 374    315
# 375    304
# 376    297
# 377    290
# 378    303
# 379    311
# 380    322
# 381    319
# 382    324
# 383    300
# 384    340
# 385    335
# 386    302
# 387    307
# 388    296
# 389    320
# 390    314
# 391    318
# 392    326
# 393    317
# 394    329
# 395    324
# 396    325
# 397    330
# 398    312
# 399    333
# Name: GRE_Score, Length: 400, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
ax=plt.plot(GRE,COA,'o')
plt.ylabel("COA")
plt.xlabel("GRE_Score")
# Out:
# Text(0.5, 0, 'GRE_Score')

# %%
data.corr()
# Out:
#                    GRE_Score  TOEFL_Score  University_Rating       SOP  \
# GRE_Score           1.000000     0.835977           0.668976  0.612831
# TOEFL_Score         0.835977     1.000000           0.695590  0.657981
# University_Rating   0.668976     0.695590           1.000000  0.734523
# SOP                 0.612831     0.657981           0.734523  1.000000
# LOR                 0.557555     0.567721           0.660123  0.729593
# CGPA                0.833060     0.828417           0.746479  0.718144
# Research            0.580391     0.489858           0.447783  0.444029
# COA                 0.802610     0.791594           0.711250  0.675732
#
#                         LOR      CGPA  Research       COA
# GRE_Score          0.557555  0.833060  0.580391  0.802610
# TOEFL_Score        0.567721  0.828417  0.489858  0.791594
# University_Rating  0.660123  0.746479  0.447783  0.711250
# SOP                0.729593  0.718144  0.444029  0.675732
# ...

# %%
data.cov()
# Out:
#                     GRE_Score  TOEFL_Score  University_Rating       SOP  \
# GRE_Score          131.644555    58.216967           8.778791  7.079699
# TOEFL_Score         58.216967    36.838997           4.828697  4.021053
# University_Rating    8.778791     4.828697           1.308114  0.845865
# SOP                  7.079699     4.021053           0.845865  1.013784
# LOR                  5.747726     3.095965           0.678352  0.660025
# CGPA                 5.699742     2.998337           0.509117  0.431183
# Research             3.318690     1.481729           0.255232  0.222807
# COA                  1.313271     0.685179           0.116009  0.097028
#
#                         LOR      CGPA  Research       COA
# GRE_Score          5.747726  5.699742  3.318690  1.313271
# TOEFL_Score        3.095965  2.998337  1.481729  0.685179
# University_Rating  0.678352  0.509117  0.255232  0.116009
# SOP                0.660025  0.431183  0.222807  0.097028
# ...

# %%
mean_COA= data['COA'].mean()
mean_COA
# Out:
# 0.7243499999999996

# %%
plt.plot(GRE,COA,'o')
plt.ylabel("COA")
plt.xlabel("GRE_Score")
plt.axhline(mean_COA, color='r', linestyle='-')
plt.show()

# %%
import statsmodels.api as sm
model=sm.OLS(COA,GRE).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    COA   R-squared:                       0.973
# Model:                            OLS   Adj. R-squared:                  0.972
# Method:                 Least Squares   F-statistic:                 1.412e+04
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):          1.49e-313
# Time:                        11:40:14   Log-Likelihood:                 272.73
# No. Observations:                 400   AIC:                            -543.5
# Df Residuals:                     399   BIC:                            -539.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# GRE_Score      0.0023   1.93e-05    118.843      0.000       0.002       0.002
# ...

# %%
import seaborn as sns
sns.pairplot(data)

# %%
sns.distplot(data['GRE_Score'])

# %%
corr = data.corr()
sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns)

# %%
plt.plot(GRE,COA,'o')
plt.ylabel("COA")
plt.xlabel("GRE_Score")
plt.axhline(mean_COA, color='r', linestyle='-')
sns.regplot(x='GRE_Score', y='COA', data=data)

# %%
X=data['GRE_Score']
y=data['COA']

# %%
X
# Out:
# 0      337
# 1      324
# 2      316
# 3      322
# 4      314
# 5      330
# 6      321
# 7      308
# 8      302
# 9      323
# 10     325
# 11     327
# 12     328
# 13     307
# 14     311
# 15     314
# 16     317
# 17     319
# 18     318
# 19     303
# 20     312
# 21     325
# 22     328
# 23     334
# 24     336
# 25     340
# 26     322
# 27     298
# 28     295
# 29     310
#       ...
# 370    310
# 371    324
# 372    336
# 373    321
# 374    315
# 375    304
# 376    297
# 377    290
# 378    303
# 379    311
# 380    322
# 381    319
# 382    324
# 383    300
# 384    340
# 385    335
# 386    302
# 387    307
# 388    296
# 389    320
# 390    314
# 391    318
# 392    326
# 393    317
# 394    329
# 395    324
# 396    325
# 397    330
# 398    312
# 399    333
# Name: GRE_Score, Length: 400, dtype: int64

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
# 5      0.90
# 6      0.75
# 7      0.68
# 8      0.50
# 9      0.45
# 10     0.52
# 11     0.84
# 12     0.78
# 13     0.62
# 14     0.61
# 15     0.54
# 16     0.66
# 17     0.65
# 18     0.63
# 19     0.62
# 20     0.64
# 21     0.70
# 22     0.94
# 23     0.95
# 24     0.97
# 25     0.94
# 26     0.76
# 27     0.44
# 28     0.46
# 29     0.54
#        ...
# 370    0.72
# 371    0.89
# 372    0.95
# 373    0.79
# 374    0.39
# 375    0.38
# 376    0.34
# 377    0.47
# 378    0.56
# 379    0.71
# 380    0.78
# 381    0.73
# 382    0.82
# 383    0.62
# 384    0.96
# 385    0.96
# 386    0.46
# 387    0.53
# 388    0.49
# 389    0.76
# 390    0.64
# 391    0.71
# 392    0.84
# 393    0.77
# 394    0.89
# 395    0.82
# 396    0.84
# 397    0.91
# 398    0.67
# 399    0.95
# Name: COA, Length: 400, dtype: float64

# %%
from sklearn.model_selection import train_test_split   
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.4,random_state =1)

# %%
X_train
# Out:
# 163    317
# 247    311
# 378    303
# 145    320
# 251    316
# 42     313
# 160    315
# 230    313
# 191    323
# 238    310
# 344    295
# 392    326
# 330    327
# 285    331
# 192    322
# 147    326
# 304    313
# 100    322
# 34     331
# 110    305
# 175    320
# 245    328
# 135    314
# 374    315
# 154    326
# 19     303
# 142    331
# 158    306
# 273    312
# 44     326
#       ...
# 317    300
# 319    327
# 7      308
# 141    332
# 86     315
# 352    303
# 241    317
# 215    330
# 68     318
# 50     313
# 156    315
# 252    318
# 357    301
# 254    321
# 276    329
# 178    309
# 281    317
# 237    329
# 71     336
# 129    333
# 144    325
# 335    325
# 133    323
# 203    334
# 393    317
# 255    307
# 72     321
# 396    325
# 235    326
# 37     300
# Name: GRE_Score, Length: 240, dtype: int64

# %%
y_train
# Out:
# 163    0.68
# 247    0.71
# 378    0.56
# 145    0.81
# 251    0.70
# 42     0.53
# 160    0.57
# 230    0.73
# 191    0.87
# 238    0.70
# 344    0.47
# 392    0.84
# 330    0.80
# 285    0.93
# 192    0.86
# 147    0.83
# 304    0.62
# 100    0.71
# 34     0.94
# 110    0.61
# 175    0.85
# 245    0.81
# 135    0.82
# 374    0.39
# 154    0.80
# 19     0.62
# 142    0.92
# 158    0.61
# 273    0.52
# 44     0.91
#        ...
# 317    0.58
# 319    0.80
# 7      0.68
# 141    0.90
# 86     0.72
# 352    0.64
# 241    0.65
# 215    0.93
# 68     0.68
# 50     0.76
# 156    0.70
# 252    0.71
# 357    0.68
# 254    0.85
# 276    0.89
# 178    0.72
# 281    0.80
# 237    0.86
# 71     0.96
# 129    0.92
# 144    0.80
# 335    0.83
# 133    0.79
# 203    0.97
# 393    0.77
# 255    0.79
# 72     0.93
# 396    0.84
# 235    0.88
# 37     0.58
# Name: COA, Length: 240, dtype: float64

# %%
X_train = X_train.values.reshape(-1,1)

# %%
X_train
# Out:
# array([[317],
#        [311],
#        [303],
#        [320],
#        [316],
#        [313],
#        [315],
#        [313],
#        [323],
#        [310],
#        [295],
#        [326],
#        [327],
#        [331],
#        [322],
#        [326],
#        [313],
#        [322],
#        [331],
#        [305],
#        [320],
#        [328],
#        [314],
#        [315],
#        [326],
#        [303],
#        [331],
#        [306],
#        [312],
#        [326],
#        [299],
#        [325],
#        [321],
#        [331],
#        [316],
#        [311],
#        [294],
#        [311],
#        [340],
#        [302],
#        [330],
#        [323],
#        [302],
#        [297],
#        [317],
#        [295],
#        [327],
#        [320],
#        [318],
#        [338],
#        [315],
#        [321],
#        [311],
#        [324],
#        [326],
#        [340],
#        [314],
#        [320],
#        [323],
#        [315],
#        [309],
#        [326],
# ...

# %%
y_train
# Out:
# 163    0.68
# 247    0.71
# 378    0.56
# 145    0.81
# 251    0.70
# 42     0.53
# 160    0.57
# 230    0.73
# 191    0.87
# 238    0.70
# 344    0.47
# 392    0.84
# 330    0.80
# 285    0.93
# 192    0.86
# 147    0.83
# 304    0.62
# 100    0.71
# 34     0.94
# 110    0.61
# 175    0.85
# 245    0.81
# 135    0.82
# 374    0.39
# 154    0.80
# 19     0.62
# 142    0.92
# 158    0.61
# 273    0.52
# 44     0.91
#        ...
# 317    0.58
# 319    0.80
# 7      0.68
# 141    0.90
# 86     0.72
# 352    0.64
# 241    0.65
# 215    0.93
# 68     0.68
# 50     0.76
# 156    0.70
# 252    0.71
# 357    0.68
# 254    0.85
# 276    0.89
# 178    0.72
# 281    0.80
# 237    0.86
# 71     0.96
# 129    0.92
# 144    0.80
# 335    0.83
# 133    0.79
# 203    0.97
# 393    0.77
# 255    0.79
# 72     0.93
# 396    0.84
# 235    0.88
# 37     0.58
# Name: COA, Length: 240, dtype: float64

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X_train,y_train)

# %%
acc=model.score(X_train,y_train)
acc
# Out:
# 0.6254287346177883

# %%
X = data[["CGPA", "GRE_Score","TOEFL_Score","University_Rating","SOP","LOR","Research"]]
y = data["COA"]

# %%
model1 = sm.OLS(y,X).fit()
predictions = model1.predict(X)
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    COA   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     6034.
# Date:                Fri, 21 Jun 2019   Prob (F-statistic):               0.00
# Time:                        11:40:28   Log-Likelihood:                 491.14
# No. Observations:                 400   AIC:                            -968.3
# Df Residuals:                     393   BIC:                            -940.3
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.4, random_state=1)

# %%
X_train
# Out:
#      CGPA  GRE_Score  TOEFL_Score  University_Rating  SOP  LOR  Research
# 163  8.56        317          105                  3  3.5  3.0         0
# 247  8.48        311          104                  2  2.5  3.5         0
# 378  7.65        303           98                  1  2.0  2.5         0
# 145  8.64        320          113                  2  2.0  2.5         1
# 251  9.00        316           99                  2  2.5  3.0         0
# 42   8.50        313          107                  2  2.5  2.0         1
# 160  7.86        315          103                  1  1.5  2.0         0
# 230  8.65        313          104                  3  4.0  4.5         0
# 191  8.98        323          110                  5  4.0  5.0         1
# 238  8.37        310          104                  3  2.0  3.5         0
# 344  7.34        295           96                  2  1.5  2.0         0
# 392  9.12        326          112                  4  4.0  3.5         1
# ...

# %%
y_train
# Out:
# 163    0.68
# 247    0.71
# 378    0.56
# 145    0.81
# 251    0.70
# 42     0.53
# 160    0.57
# 230    0.73
# 191    0.87
# 238    0.70
# 344    0.47
# 392    0.84
# 330    0.80
# 285    0.93
# 192    0.86
# 147    0.83
# 304    0.62
# 100    0.71
# 34     0.94
# 110    0.61
# 175    0.85
# 245    0.81
# 135    0.82
# 374    0.39
# 154    0.80
# 19     0.62
# 142    0.92
# 158    0.61
# 273    0.52
# 44     0.91
#        ...
# 317    0.58
# 319    0.80
# 7      0.68
# 141    0.90
# 86     0.72
# 352    0.64
# 241    0.65
# 215    0.93
# 68     0.68
# 50     0.76
# 156    0.70
# 252    0.71
# 357    0.68
# 254    0.85
# 276    0.89
# 178    0.72
# 281    0.80
# 237    0.86
# 71     0.96
# 129    0.92
# 144    0.80
# 335    0.83
# 133    0.79
# 203    0.97
# 393    0.77
# 255    0.79
# 72     0.93
# 396    0.84
# 235    0.88
# 37     0.58
# Name: COA, Length: 240, dtype: float64

# %%
features= X_train.iloc[:,:].values
features
# Out:
# array([[  8.56, 317.  , 105.  , ...,   3.5 ,   3.  ,   0.  ],
#        [  8.48, 311.  , 104.  , ...,   2.5 ,   3.5 ,   0.  ],
#        [  7.65, 303.  ,  98.  , ...,   2.  ,   2.5 ,   0.  ],
#        ...,
#        [  9.11, 325.  , 107.  , ...,   3.  ,   3.5 ,   1.  ],
#        [  9.23, 326.  , 111.  , ...,   4.5 ,   4.  ,   1.  ],
#        [  7.8 , 300.  , 105.  , ...,   1.  ,   2.  ,   0.  ]])

# %%
labels = y_train.iloc[:].values
labels
# Out:
# array([0.68, 0.71, 0.56, 0.81, 0.7 , 0.53, 0.57, 0.73, 0.87, 0.7 , 0.47,
#        0.84, 0.8 , 0.93, 0.86, 0.83, 0.62, 0.71, 0.94, 0.61, 0.85, 0.81,
#        0.82, 0.39, 0.8 , 0.62, 0.92, 0.61, 0.52, 0.91, 0.54, 0.85, 0.77,
#        0.93, 0.49, 0.65, 0.46, 0.71, 0.94, 0.5 , 0.86, 0.79, 0.57, 0.43,
#        0.75, 0.46, 0.74, 0.64, 0.71, 0.91, 0.58, 0.82, 0.73, 0.78, 0.79,
#        0.9 , 0.73, 0.88, 0.73, 0.56, 0.65, 0.84, 0.86, 0.69, 0.61, 0.76,
#        0.62, 0.71, 0.78, 0.64, 0.62, 0.88, 0.63, 0.64, 0.75, 0.89, 0.72,
#        0.82, 0.74, 0.74, 0.46, 0.7 , 0.64, 0.81, 0.78, 0.72, 0.72, 0.96,
#        0.71, 0.97, 0.81, 0.93, 0.72, 0.57, 0.89, 0.79, 0.56, 0.95, 0.91,
#        0.59, 0.94, 0.74, 0.85, 0.64, 0.65, 0.61, 0.56, 0.71, 0.86, 0.59,
#        0.47, 0.66, 0.68, 0.47, 0.7 , 0.9 , 0.77, 0.7 , 0.68, 0.69, 0.57,
#        0.76, 0.96, 0.58, 0.48, 0.36, 0.94, 0.84, 0.96, 0.97, 0.86, 0.63,
#        0.52, 0.77, 0.48, 0.79, 0.6 , 0.46, 0.79, 0.64, 0.81, 0.64, 0.63,
# ...

# %%
X=features
y=labels

# %%
from sklearn import linear_model as lm
model=lm.LinearRegression()
results=model.fit(X,y)

# %%
predictions = model.predict(X)

# %%
accuracy=model.score(X,y)
print('Accuracy of the model:', accuracy)
# Out:
# Accuracy of the model: 0.8089860244349504

# %%
plt.scatter(y, predictions)

# %%
from sklearn.metrics import mean_squared_error, r2_score
print('Slope:' ,model.coef_)
print('Intercept:', model.intercept_)
print("\n")
import numpy as np
rmse = (np.sqrt(mean_squared_error(y,predictions)))
r2 = r2_score(y,predictions)
print("The model performance")
print("--------------------------------------")
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
print("\n")
# Out:
# Slope: [ 0.10358629  0.00123569  0.00301196  0.01053834 -0.00021071  0.02044726
#   0.02960009]
# Intercept: -0.9934556643670455
#
#
# The model performance
# --------------------------------------
# RMSE is 0.059659691676880754
# R2 score is 0.8089860244349504
